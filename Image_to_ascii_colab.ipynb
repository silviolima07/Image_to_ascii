# %% [markdown]
# <a href="https://colab.research.google.com/github/silviolima07/Image_to_ascii/blob/main/Image_to_ascii_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1

# %%
# !pip install pywhatkit
# Out:
# ...
#      |████████████████████████████████| 61kB 3.9MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 133kB 16.3MB/s
# ...
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-cp37-none-any.whl size=7420 sha256=f37c396eb684c9e84a6af31f7fd4e150b78177fd0e71ef4b83cce6232a3a07e1
#   Stored in directory: /root/.cache/pip/wheels/16/d7/4e/fffdd54b1cca86608b7655c9a2854890a38f955ce9532848cd
# ...
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.27-cp37-none-any.whl size=12891 sha256=5f289d351385ab464225b6b6ac57791aa2a2b673c2014e4c5229a59067c8c7e9
#   Stored in directory: /root/.cache/pip/wheels/4d/c1/33/e7a099b5906e1110c51d32c957ad56df5a9976cd43153398df
# Successfully built pymsgbox pyscreeze
# ...

# %%
from IPython import display as ipythondisplay

# %%
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start()

# %%
# !touch /root/.Xauthority

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img=mpimg.imread('/content/senna.jpeg')

# %%
imgplot = plt.imshow(img)

# %%
from pywhatkit import image_to_ascii_art

# Caminho da imagem
entrada_img = '/content/senna.jpeg'

# Caminho da saida
saida_arquivo_txt = 'ascii_python.txt'

# Esta função cria um arquivo e é possível imprimir a arte
print(image_to_ascii_art(imgpath=entrada_img, output_file=saida_arquivo_txt));
# Out:
# Xlib.xauth: warning, no xauthority details available
# Xlib.xauth: warning, no xauthority details available
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@$@@$$$@@@$$$$@@@@@$$$@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@@@@@$@@$$@@@@@@@@@@@@@$$$$$$@$$$$$$$$$$$$$$@$$$$$$$$$$$$$$$$$$$$$$@@@@
# @@@@@@@@@@@@$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# @@@@$$$@@$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$@&&&&&&&@@$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$@@&&##SSSSS###&@$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$@&#####SSSS####SS#@$$$$$$$$$$$$$$$$$$$$$$$$$$$
# ...
